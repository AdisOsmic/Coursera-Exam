# %% [markdown]
# <H1> My Jupyter Notebook on IBM Watson Studio</H1>

# %% [markdown]
# <b> Adis Osmic </b> <br>
# I would like to be a Data Scientist and programmer

# %% [markdown]
# <i> I am interested in Data Science because of Machine Learning and programming in general. I would like to be able to create simple text bots. </i>

# %% [markdown]
# <H3> In the following code, we will simply add two numbers together </H3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# <hr>Here is the horizontal rule</hr>
# <ul>
# <li> <s>Item 1</s> </li>
# <li> Item 2 </li>
# </ul>
# <ol>
# <li> Item 3 </li>
# <li> <a href=https://www.youtube.com/watch?v=dQw4w9WgXcQ> Item 4 </a> </li>
# </ol>
# <table>
#     <tr>
#         <th> P </th>
#         <th> Q </th>
#         <th> P <it>and</it> Q </th>
#     </tr>
#     <tr>
#         <th> 0 </th>
#         <th> 0 </th>
#         <th> 0 </th>
#     </tr>
#     <tr>
#         <th> 1 </th>
#         <th> 0 </th>
#         <th> 0 </th>
#     </tr>
#     <tr>
#         <th> 0 </th>
#         <th> 1 </th>
#         <th> 0 </th>
#     </tr>
#     <tr>
#         <th> 1 </th>
#         <th> 1 </th>
#         <th> 1 </th>
#     </tr>
# </table>
#
# <image src="https://www.thetimes.co.uk/imageserver/image/%2Fmethode%2Fsundaytimes%2Fprod%2Fweb%2Fbin%2Fe6496bba-3356-11ec-91da-063c6e372e74.jpg?crop=2667%2C1500%2C0%2C0&resize=1500">
